# %% [markdown]
# # Bicubic Interpolation

# %%
# %run bicubic_interpolation.py
# Out:
# Iteration number:  1
# Iteration number:  2
# Iteration number:  3
# Shape of Original Image:  (61, 61, 3)
# Shape of New Image     :  (122, 122, 3)
# Scaling factor         :  4
# Execution time         :  2 sec

# %%
# %run bicubic_interpolation.py
# Out:
# Iteration number:  1
# Iteration number:  2
# Shape of Original Image:  (48, 72, 3)
# Shape of New Image     :  (96, 144, 3)
# Scaling factor         :  4
# Execution time         :  1 sec

# %%
# %run bicubic_interpolation.py
# Out:
# Iteration number:  1
# Iteration number:  2
# Iteration number:  3
# Iteration number:  4
# Shape of Original Image:  (48, 72, 3)
# Shape of New Image     :  (192, 288, 3)
# Scaling factor         :  8
# Execution time         :  12 sec

# %%
# %run bicubic_interpolation.py
# Out:
# Iteration number:  1
# Iteration number:  2
# Shape of Original Image:  (48, 72, 3)
# Shape of New Image     :  (96, 144, 3)
# Scaling factor         :  4
# Execution time         :  2 sec

# %%
# %run bicubic_interpolation.py
# Out:
# Iteration number:  1
# Iteration number:  2
# Iteration number:  3
# Iteration number:  4
# Shape of Original Image:  (48, 72, 3)
# Shape of New Image     :  (192, 288, 3)
# Scaling factor         :  8
# Execution time         :  12 sec

# %%
# %run bicubic_interpolation.py
# Out:
# Iteration number:  1
# Iteration number:  2
# Iteration number:  3
# Shape of Original Image:  (80, 120, 3)
# Shape of New Image     :  (320, 480, 3)
# Scaling factor         :  8
# Execution time         :  23 sec

# %%
# %run bicubic_interpolation.py
# Out:
# Iteration number:  1
# Iteration number:  2
# Iteration number:  3
# Iteration number:  4
# Iteration number:  5
# Iteration number:  6
# Iteration number:  7
# Shape of Original Image:  (80, 120, 3)
# Shape of New Image     :  (320, 480, 3)
# Scaling factor         :  8
# Execution time         :  60 sec

# %%
# %run bicubic_interpolation.py
# Out:
# Iteration number:  1
# Iteration number:  2
# Iteration number:  3
# Iteration number:  4
# Iteration number:  5
# Iteration number:  6
# Iteration number:  7
# Shape of Original Image:  (80, 120, 3)
# Shape of New Image     :  (320, 480, 3)
# Scaling factor         :  8
# Execution time         :  64 sec
